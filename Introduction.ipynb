# %% [markdown]
# # MECH 416: Introduction to Robotic Manipulators
#
# This is the companion online book for *Introduction to Robotic Manipulators* (MECH 416) at Colorado State University. It is under continuous development by Dr. Jianguo Zhao and will be updated periodically as the course is taught.
#
# ### Why a new robotics book?
#
# Most existing robotics textbooks are purely theoretical. Can we have a book that blends rigor with practice?
#
# This online, interactive book tries to do exactly that. On one hand, we want to retain the rigor expected of a robotics fundamentals text. On the other hand, we want to show that the theory can be applied directly, both in simulation and on real hardware.
#
# We start with the same theoretical foundations as traditional robotics textbooks. But we also include numerical implementations in Python to solve problems such as forward and inverse kinematics, the Jacobian, trajectory generation, and dynamics and control, to name a few.
#
# Beyond these numerical implementations, we use MuJoCo to illustrate more complex robotic systems, simulating the kinematics and dynamics of open-source robot models directly.
#
# Finally, we present two levels of hardware for implementing the theory and simulation:
#
# - **Level 1 — Kinematics.** This level relies on smart bus servo motors that can directly control angle or speed. We will either build a simple robotic arm, such as a planar 2R arm, or use an existing low-cost, open-source arm like the SO-ARM101.
# - **Level 2 — Dynamics and control.** This level is based on quasi-direct-drive motors, which can be controlled directly by torque. These can also be used to build a planar 2R robot, but they let us implement dynamics-based controllers, such as computed-torque control.
#
# ### How This Book Is Organized
#
# Each theoretical chapter is paired with hands-on labs on one of the two hardware tiers above — Level 1 (kinematics, smart bus servos) or Level 2 (dynamics and control, quasi-direct-drive motors).
#
# **Chapters**
#
# | # | Chapter | Status |
# |---|---|---|
# | 1 | Introduction *(this chapter)* | ✅ Published |
# | 2 | Actuators for Robotics | ✅ Published |
# | 3 | Kinematics in 2D | ✅ Published |
# | 4 | Homogeneous Transformations | 🚧 In progress |
# | 5+ | Position/Velocity Kinematics in 3D, Dynamics, and Control | 📝 Planned |
#
# **Labs — Level 1: Robot Kinematics**
#
# Eight labs are planned for this level:
#
# | # | Lab |
# |---|---|
# | 1 | Intro to Python |
# | 2 | Controlling Motors |
# | 3 | Build a 2R Robot and Control It |
# | 4 | Build the SO-ARM101 |
# | 5 | SO-ARM101 Joint Control |
# | 6 | SO-ARM101 Forward Kinematics |
# | 7 | SO-ARM101 Inverse Kinematics |
# | 8 | SO-ARM101 Trajectory Generation |
#
# **Labs — Level 2: Robot Dynamics**
#
# To be developed later, once the corresponding dynamics and control chapters are in place.
#
# > Labs aren't part of this online book yet — they'll be added here as the corresponding chapters are published.
#
# ### Acknowledgements
#
# Part of the SO-ARM101 labs in this book are inspired by Prof. Maegan Tucker's ECE 4560 course at Georgia Tech, particularly her [SO-101 robot arm lab track](https://maegantucker.com/ECE4560/so101/). Many thanks to her for making these materials openly available.
